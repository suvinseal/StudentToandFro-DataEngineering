# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Students17.csv")

# %%
df.head()
# Out:
#    OBJECTID  USA_ZIP_Codes_250MileBuffer__1  zipcodeX  ziocodeY    CaCx  \
# 0         1                            6001    745616    466437  480375
# 1         2                            6010    738613    453584  480375
# 2         3                            6019    739897    471276  480375
# 3         4                            6426    785930    418924  480375
# 4         5                            6443    768125    411339  480375
#
#      CaCy   Shape_Length
# 0  172622  395828.372489
# 1  172622  381610.481065
# 2  172622  395658.864035
# 3  172622  392464.773077
# 4  172622  373879.552067

# %%
df.columns = ['ID','studentZIP','cityX','cityY','CaCx','CaCy','distance_feet']

# %%
df.head()
# Out:
#    ID  studentZIP   cityX   cityY    CaCx    CaCy  distance_feet
# 0   1        6001  745616  466437  480375  172622  395828.372489
# 1   2        6010  738613  453584  480375  172622  381610.481065
# 2   3        6019  739897  471276  480375  172622  395658.864035
# 3   4        6426  785930  418924  480375  172622  392464.773077
# 4   5        6443  768125  411339  480375  172622  373879.552067

# %%
df['distance_miles'] = df['distance_feet']*0.000189394

# %%
df.head()
# Out:
#    ID  studentZIP   cityX   cityY    CaCx    CaCy  distance_feet  \
# 0   1        6001  745616  466437  480375  172622  395828.372489
# 1   2        6010  738613  453584  480375  172622  381610.481065
# 2   3        6019  739897  471276  480375  172622  395658.864035
# 3   4        6426  785930  418924  480375  172622  392464.773077
# 4   5        6443  768125  411339  480375  172622  373879.552067
#
#    distance_miles
# 0       74.967519
# 1       72.274735
# 2       74.935415
# 3       74.330473
# 4       70.810544

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
